# %%
import unittest
from decimal import Decimal
import pandas as pd
import theta.core as tc
from theta.helper import tick_to_sqrtPriceX96,quote_price_to_tick, sqrt_price_to_tick, tick_to_quote_price, sqrtPriceX96_to_quote_price, quote_price_to_tick_nobase
from theta.liquitidy_math import get_liquidity_for_amount0, get_liquidity_for_amount1, get_liquidity

# %%
BTC1 = tc.get_avg_fee(   
    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/arb_WBTC_WETH_0.05",
    tc.PoolInfo(True, 8, 18, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.89"),
    Decimal("1.12"),
    Decimal("0.0696864111")

)
# Out:
# 2023-06-04 00:00:00
#          date                      lower_price  \
# 45 2023-06-04  0.06953643371285975778421929756
# 24 2023-06-03  0.06955034242312890116480918595
# 23 2023-06-02  0.06934956229914602938661048394
# 11 2023-06-01  0.06875530592256208622138245957
# 21 2023-05-31  0.06836341703517327211349777020
# 22 2023-05-30  0.06817710938243787937515215022
# 16 2023-05-29  0.06771237697935157266331801859
# 15 2023-05-28  0.06685543608866085974874370744
# 32 2023-05-27  0.06813430507930521351922965183
# 31 2023-05-26  0.06810140108783341704563082735
# 4  2023-05-25  0.06779190334244949152511510851
# 5  2023-05-24  0.06785376953436215936325456207
# 20 2023-05-23  0.06756722214414366261662172902
# 19 2023-05-22  0.06729990993479579333578314303
# 37 2023-05-21  0.06692380617341894437627496509
# 38 2023-05-20  0.06713464558157287790969066566
# 28 2023-05-19  0.06708360762460468558776786308
# 27 2023-05-18  0.06644387684916386855106090637
# ...

# %%
BTC1 = tc.get_avg_fee(   
    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/arb_WBTC_WETH_0.05",
    tc.PoolInfo(True, 8, 18, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.89"),
    Decimal("1.12"),
    Decimal("0.0696864111")

)
# Out:
# 2023-06-04 00:00:00
#          date                      lower_price  \
# 45 2023-06-04  0.06953643371285975778421929756
# 24 2023-06-03  0.06955034242312890116480918595
# 23 2023-06-02  0.06934956229914602938661048394
# 11 2023-06-01  0.06875530592256208622138245957
# 21 2023-05-31  0.06836341703517327211349777020
# 22 2023-05-30  0.06817710938243787937515215022
# 16 2023-05-29  0.06771237697935157266331801859
# 15 2023-05-28  0.06685543608866085974874370744
# 32 2023-05-27  0.06813430507930521351922965183
# 31 2023-05-26  0.06810140108783341704563082735
# 4  2023-05-25  0.06779190334244949152511510851
# 5  2023-05-24  0.06785376953436215936325456207
# 20 2023-05-23  0.06756722214414366261662172902
# 19 2023-05-22  0.06729990993479579333578314303
# 37 2023-05-21  0.06692380617341894437627496509
# 38 2023-05-20  0.06713464558157287790969066566
# 28 2023-05-19  0.06708360762460468558776786308
# 27 2023-05-18  0.06644387684916386855106090637
# ...

# %%
BTC2 = tc.get_avg_fee(   
    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/arb_WBTC_WETH_0.05",
    tc.PoolInfo(True, 8, 18, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.92"),
    Decimal("1.09"),
    Decimal("0.0696864111")

)
# Out:
# 2023-06-04 00:00:00
#          date                      lower_price  \
# 45 2023-06-04  0.06953643371285975778421929756
# 24 2023-06-03  0.06955034242312890116480918595
# 23 2023-06-02  0.06934956229914602938661048394
# 11 2023-06-01  0.06875530592256208622138245957
# 21 2023-05-31  0.06836341703517327211349777020
# 22 2023-05-30  0.06817710938243787937515215022
# 16 2023-05-29  0.06771237697935157266331801859
# 15 2023-05-28  0.06685543608866085974874370744
# 32 2023-05-27  0.06813430507930521351922965183
# 31 2023-05-26  0.06810140108783341704563082735
# 4  2023-05-25  0.06779190334244949152511510851
# 5  2023-05-24  0.06785376953436215936325456207
# 20 2023-05-23  0.06756722214414366261662172902
# 19 2023-05-22  0.06729990993479579333578314303
# 37 2023-05-21  0.06692380617341894437627496509
# 38 2023-05-20  0.06713464558157287790969066566
# 28 2023-05-19  0.06708360762460468558776786308
# 27 2023-05-18  0.06644387684916386855106090637
# ...

# %%
BTC3 = tc.get_avg_fee(   
    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/arb_WBTC_WETH_0.05",
    tc.PoolInfo(True, 8, 18, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.94"),
    Decimal("1.06"),
    Decimal("0.0696864111")

)

print(BTC1,BTC2,BTC3)
# Out:
# 2023-06-04 00:00:00
#          date                      lower_price  \
# 45 2023-06-04  0.06953643371285975778421929756
# 24 2023-06-03  0.06955034242312890116480918595
# 23 2023-06-02  0.06934956229914602938661048394
# 11 2023-06-01  0.06875530592256208622138245957
# 21 2023-05-31  0.06836341703517327211349777020
# 22 2023-05-30  0.06817710938243787937515215022
# 16 2023-05-29  0.06771237697935157266331801859
# 15 2023-05-28  0.06685543608866085974874370744
# 32 2023-05-27  0.06813430507930521351922965183
# 31 2023-05-26  0.06810140108783341704563082735
# 4  2023-05-25  0.06779190334244949152511510851
# 5  2023-05-24  0.06785376953436215936325456207
# 20 2023-05-23  0.06756722214414366261662172902
# 19 2023-05-22  0.06729990993479579333578314303
# 37 2023-05-21  0.06692380617341894437627496509
# 38 2023-05-20  0.06713464558157287790969066566
# 28 2023-05-19  0.06708360762460468558776786308
# 27 2023-05-18  0.06644387684916386855106090637
# ...

# %%
test1 = tc.get_uniswap_theta("/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/eth_WETH_USDT_0.05/ethereum-0x11b815efb8f581194ae79006d24e0d814b7697f6-2023-05-29.tick.csv",
tc.PoolInfo(False, 18, 6, Decimal(0.05), base_amount=Decimal(1000)),
            Decimal("0.87"),
            Decimal("1.15"),
            Decimal("1850") )


print(test1)
# Out:
# 0.0007449042259924033852158711242

# %%
eth_usdc_0051 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/eth_USDC_WETH_0.05",
    tc.PoolInfo(True, 6, 18, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.87"),
    Decimal("1.15"),
    Decimal("1860")
)

eth_usdc_0052 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/eth_USDC_WETH_0.05",
    tc.PoolInfo(True, 6, 18, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.83"),
    Decimal("1.2"),
    Decimal("1860")
)
eth_usdc_0053 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/eth_USDC_WETH_0.05",
    tc.PoolInfo(True, 6, 18, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.8"),
    Decimal("1.25"),
    Decimal("1860")
)
print(eth_usdc_0051,eth_usdc_0052,eth_usdc_0053)

# %%
eth_usdt_0051 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/eth_WETH_USDT_0.05",
    tc.PoolInfo(False, 18, 6, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.87"),
    Decimal("1.15"),
    Decimal("1860")
)

eth_usdt_0052 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/eth_WETH_USDT_0.05",
    tc.PoolInfo(False, 18, 6, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.83"),
    Decimal("1.2"),
    Decimal("1860")
)
eth_usdt_0053 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/eth_WETH_USDT_0.05",
    tc.PoolInfo(False, 18, 6, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.8"),
    Decimal("1.25"),
    Decimal("1860")
)
print(eth_usdt_0051,eth_usdt_0052,eth_usdt_0053)

# %%
arb_usdt_0051 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/arb_WETH_USDT_0.05",
    tc.PoolInfo(False, 18, 6, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.87"),
    Decimal("1.15"),
    Decimal("1860")
)

arb_usdt_0052 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/arb_WETH_USDT_0.05",
    tc.PoolInfo(False, 18, 6, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.83"),
    Decimal("1.2"),
    Decimal("1860")
)
arb_usdt_0053 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/arb_WETH_USDT_0.05",
    tc.PoolInfo(False, 18, 6, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.8"),
    Decimal("1.25"),
    Decimal("1860")
)
print(arb_usdt_0051,arb_usdt_0052,arb_usdt_0053)
# Out:
# 2023-05-29 00:00:00
#          date                    lower_price                    upper_price  \
# 19 2023-05-29  1874.815810233533953706277398  1924.994841535866742415064390
# 18 2023-05-28  1824.624609633704053670509399  1915.449640907561979223116658
# 29 2023-05-27  1814.866371810236901350341313  1835.303527530360107469756792
# 28 2023-05-26  1798.088967191698706493180345  1836.710383168632466689008824
# 4  2023-05-25  1767.332688829855234612591856  1816.950832442789189749368106
# 5  2023-05-24  1782.479336190865848093754557  1853.743676807059177260701033
# 15 2023-05-23  1816.089544219540393631787610  1868.857609183032753852110709
# 14 2023-05-22  1790.930137092134395829453794  1826.628702621495343737630750
# 36 2023-05-21  1800.643924212484722646467120  1829.519202384303159194466832
# 37 2023-05-20  1808.303503001229182745630062  1827.443672842227972954309419
# 27 2023-05-19  1797.860467286425272466872754  1829.278734451048766815715902
# ...

# %%
arb_usdt_0052 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/arb_WETH_USDT_0.05",
    tc.PoolInfo(False, 18, 6, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.83"),
    Decimal("1.2"),
    Decimal("1860")
)
# Out:
# 2023-06-04 00:00:00
#          date                    lower_price                    upper_price  \
# 47 2023-06-04  1885.660003782596706124603766  1912.880421741632306021882450
# 26 2023-06-03  1884.036981573941905325741336  1908.019783058914052185412584
# 25 2023-06-02  1849.094298181900338001611849  1912.371783561592331723544642
# 9  2023-06-01  1845.321576177005404586318473  1887.767156999234609912863000
# 23 2023-05-31  1852.567837586012660022158301  1906.584176784119550185857519
# 24 2023-05-30  1882.508806569789598531651902  1916.581667755885444948276495
# 20 2023-05-29  1874.815810233533953706277398  1924.994841535866742415064390
# 19 2023-05-28  1824.624609633704053670509399  1915.449640907561979223116658
# 34 2023-05-27  1814.866371810236901350341313  1835.303527530360107469756792
# 33 2023-05-26  1798.088967191698706493180345  1836.710383168632466689008824
# 4  2023-05-25  1767.332688829855234612591856  1816.950832442789189749368106
# ...

# %%
arb_usdc_0052 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/arb_WETH_USDC_0.05",
    tc.PoolInfo(False, 18, 6, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.83"),
    Decimal("1.2"),
    Decimal("1860")
)
# Out:
# /Users/wanjinwoo/Desktop/Antalpha/Github/uniswap-lib/tests/theta/core.py:247: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df: pd.DataFrame = pd.read_csv(os.path.join(from_dir, day_file), dtype={'total_liquidity': 'float','sqrtPriceX96': "float",'current_tick': "float"})
# 2023-06-04 00:00:00
#          date                    lower_price                    upper_price  \
# 24 2023-06-04  1886.182216957156658628945495  1912.945661659669120610513660
# 3  2023-06-03  1884.748105499056417730571253  1908.652809539265102339321785
# 2  2023-06-02  1850.153696839283618676791028  1912.065133612382650689108025
# 35 2023-06-01  1846.752659236280843622416562  1887.553576726055130292013223
# 4  2023-05-31  1852.997519171640213797976277  1906.857671603186167329923183
# 5  2023-05-30  1883.851602925401125608299023  1916.691981207339310900016872
# 45 2023-05-29  1875.203390742820823289919785  1924.459076410516559762153378
# ...

# %%
arb_usdc_0051 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/arb_WETH_USDC_0.05",
    tc.PoolInfo(False, 18, 6, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.87"),
    Decimal("1.15"),
    Decimal("1860")
)

arb_usdc_0052 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/arb_WETH_USDC_0.05",
    tc.PoolInfo(False, 18, 6, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.83"),
    Decimal("1.2"),
    Decimal("1860")
)

arb_usdc_0053 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/arb_WETH_USDC_0.05",
    tc.PoolInfo(False, 18, 6, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.8"),
    Decimal("1.25"),
    Decimal("1860")
)

print(arb_usdc_0051, arb_usdc_0052, arb_usdc_0053)
# Out:
# /Users/wanjinwoo/Desktop/Antalpha/Github/uniswap-lib/tests/theta/core.py:247: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df: pd.DataFrame = pd.read_csv(os.path.join(from_dir, day_file), dtype={'total_liquidity': 'float','sqrtPriceX96': "float",'current_tick': "float"})
# 2023-05-29 00:00:00
#          date                    lower_price                    upper_price  \
# 39 2023-05-29  1875.203390742820823289919785  1924.459076410516559762153378
# 38 2023-05-28  1825.134098802851495012781436  1915.076626246006794056936207
# 5  2023-05-27  1816.050180398813139837602654  1835.750885634099223225479430
# 4  2023-05-26  1798.091935978422363285610414  1837.240432659917214848067045
# 22 2023-05-25  1766.628285572783200573775187  1817.704157678276004683262196
# 23 2023-05-24  1782.659334863976159731091260  1854.078544472006643801338581
# 35 2023-05-23  1816.643633672047212765589529  1870.975879720019096500770957
# ...

# %%
eth_usdt_031 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/eth_USDC_WETH_0.3",
    tc.PoolInfo(True, 6, 18, Decimal(0.3), base_amount=Decimal(1000)),
    Decimal("0.87"),
    Decimal("1.15"),
    Decimal("1860")
)

eth_usdt_032 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/eth_USDC_WETH_0.3",
    tc.PoolInfo(True, 6, 18, Decimal(0.3), base_amount=Decimal(1000)),
    Decimal("0.83"),
    Decimal("1.2"),
    Decimal("1860")
)
eth_usdt_033 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/eth_USDC_WETH_0.3",
    tc.PoolInfo(True, 6, 18, Decimal(0.3), base_amount=Decimal(1000)),
    Decimal("0.8"),
    Decimal("1.25"),
    Decimal("1860")
)
print(eth_usdt_031,eth_usdt_032,eth_usdt_033)

# %%
eth_usdt_031 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/eth_WETH_USDT_0.3",
    tc.PoolInfo(False, 18, 6, Decimal(0.3), base_amount=Decimal(1000)),
    Decimal("0.87"),
    Decimal("1.15"),
    Decimal("1860")
)

eth_usdt_032 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/eth_WETH_USDT_0.3",
    tc.PoolInfo(False, 18, 6, Decimal(0.3), base_amount=Decimal(1000)),
    Decimal("0.83"),
    Decimal("1.2"),
    Decimal("1860")
)
eth_usdt_033 = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/eth_WETH_USDT_0.3",
    tc.PoolInfo(False, 18, 6, Decimal(0.3), base_amount=Decimal(1000)),
    Decimal("0.8"),
    Decimal("1.25"),
    Decimal("1860")
)
print(eth_usdt_031,eth_usdt_032,eth_usdt_033)
# Out:
# 2023-06-04 00:00:00
#          date                    lower_price                    upper_price  \
# 37 2023-06-04  1888.955719299600179115581487  1907.681290826998625516023897
# 31 2023-06-03  1889.339371997715357908763980  1918.700866551644493670881058
# 32 2023-06-02  1855.763940522740829018015111  1904.520386430059113958991767
# 3  2023-06-01  1848.715712544528204645162736  1881.650342735509906805114891
# 30 2023-05-31  1855.747219955173399709059402  1903.572667343706159929958448
# 29 2023-05-30  1888.748744228045256704603029  1911.157187621993070006300888
# 14 2023-05-29  1881.309085811989740871464945  1921.240069608874187664047722
# 15 2023-05-28  1828.381563277429602936176953  1912.179184448222188809585391
# 25 2023-05-27  1822.632099665026032561804965  1831.927676483631312609042196
# 26 2023-05-26  1803.106508673373860779288339  1837.485046590334402535451437
# 9  2023-05-25  1769.608996065154942344377403  1811.124194631988498145636592
# ...

# %%
arb_usdt = tc.get_avg_fee(

    "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/arb_WETH_USDT_0.05",
    tc.PoolInfo(False, 18, 6, Decimal(0.05), base_amount=Decimal(1000)),
    Decimal("0.87"),
    Decimal("1.15"),
    Decimal("1799")
)
arb_usdt

# %%
result = tc.get_uniswap_theta(
            "/Users/wanjinwoo/Desktop/Antalpha/Github/demeter-fetch/sample-data/ethereum-0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8-2023-05-16.tick.csv",
            tc.PoolInfo(True, 6, 18, Decimal(0.3), base_amount=Decimal(1000)),
            Decimal("0.8"),
            Decimal("1.25"),
            Decimal("1818")
        )

print(result)
# Out:
# 0.0002409106687353393910345519097

# %%
# test get_uniswap_theta
test1 = tc.get_uniswap_theta("/Users/wanjinwoo/Desktop/Antalpha/Github/uniswap-lib/tests/0x45dda9cb7c25131df268515131f647d726f50608-2023-03-16.csv",
tc.PoolInfo(True, 6, 18, Decimal(0.05), base_amount=Decimal(1000)),
            Decimal("0.87"),
            Decimal("1.15"),
            Decimal("1650") )


print(test1)
# Out:
# 0.001363522822399474489277560625
